# %%
import pandas as pd
#yeni kütüphane eklendiğinde bu satır tekrar çalıştırılacak

# %%
df=pd.read_csv("houses_Madrid-checkpoint.csv")
# Veri seti dahil etme

# %%
# İlk 10 satırı görüntüle
df.head(10)
# Out:
#    Unnamed: 0     id                                              title  \
# 0           0  21742              Piso en venta en calle de Godella, 64
# 1           1  21741   Piso en venta en calle de la del Manojo de Rosas
# 2           2  21740               Piso en venta en calle del Talco, 68
# 3           3  21739               Piso en venta en calle Pedro Jiménez
# 4           4  21738  Piso en venta en carretera de Villaverde a Val...
# 5           5  21737                          Piso en venta en geologia
# 6           6  21736             Piso en venta en avenida Real de Pinto
# 7           7  21735                        Piso en venta en San Andrés
# 8           8  21734                          Piso en venta en Butarque
# 9           9  21733           Piso en venta en calle de Martinez Oviol
#
#                 subtitle  sq_mt_built  sq_mt_useful  n_rooms  n_bathrooms  \
# 0  San Cristóbal, Madrid         64.0          60.0        2          1.0
# ...

# %%
df.shape
#veri setinin kaç satır ve sütundan olşutuğuna bakalım
# Out:
# (21742, 58)

# %%
df.size 
#veri setinin toplam kaç veriden oluştuğuna bakalım (21742 x 58)
# Out:
# 1261036

# %%
df.info
#veri setini inceleyelim (kaç sütun var, veri türleri neler)
# Out:
# <bound method DataFrame.info of        Unnamed: 0     id                                              title  \
# 0               0  21742              Piso en venta en calle de Godella, 64
# 1               1  21741   Piso en venta en calle de la del Manojo de Rosas
# 2               2  21740               Piso en venta en calle del Talco, 68
# 3               3  21739               Piso en venta en calle Pedro Jiménez
# 4               4  21738  Piso en venta en carretera de Villaverde a Val...
# ...           ...    ...                                                ...
# 21737       21737      5       Ático en venta en Casco Histórico de Barajas
# 21738       21738      4  Piso en venta en Urb. Campo de las Naciones - ...
# 21739       21739      3  Piso en venta en Campo de las Naciones-Corralejos
# 21740       21740      2      Chalet adosado en venta en calle Burriana, 12
# 21741       21741      1             Piso en venta en calle San Epifanio, 9
#
# ...

# %%
# veri setrindeki özniteliklere ait toplam veri sayısı, verilerin ortalaması minimum değerleri gibi bilgilerini inceleyelim
df.describe().T
#.T satır ve sütunları yer değiştirir
# Out:
#                        count           mean            std         min  \
# Unnamed: 0           21742.0   10870.500000    6276.519112         0.0
# id                   21742.0   10871.500000    6276.519112         1.0
# sq_mt_built          21616.0     146.920892     134.181865        13.0
# sq_mt_useful          8228.0     103.458192      88.259192         1.0
# n_rooms              21742.0       3.005749       1.510497         0.0
# n_bathrooms          21726.0       2.091687       1.406992         1.0
# n_floors              1437.0       3.128740       0.907713         1.0
# sq_mt_allotment       1432.0     241.692737     247.484853         1.0
# latitude                 0.0            NaN            NaN         NaN
# longitude                0.0            NaN            NaN         NaN
# portal                   0.0            NaN            NaN         NaN
# door                     0.0            NaN            NaN         NaN
# ...

# %%
#veri setinde her bir sütunda toplam kaç adet boş değer var bakalım
df.isnull().sum()
# Out:
# Unnamed: 0                          0
# id                                  0
# title                               0
# subtitle                            0
# sq_mt_built                       126
# sq_mt_useful                    13514
# n_rooms                             0
# n_bathrooms                        16
# n_floors                        20305
# sq_mt_allotment                 20310
# latitude                        21742
# longitude                       21742
# raw_address                      5465
# is_exact_address_hidden             0
# street_name                      5905
# street_number                   15442
# portal                          21742
# floor                            2607
# is_floor_under                   1170
# door                            21742
# neighborhood_id                     0
# operation                           0
# rent_price                          0
# rent_price_by_area              21742
# is_rent_price_known                 0
# ...

# %%
df=df.drop(columns=["has_private_parking","has_public_parking","is_furnished"])
#boş değer sayısı fazla olan sütunları veri setinden kaldıralım.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df=df.drop(columns=["has_private_parking","has_public_parking","is_furnished"])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
# ...
